# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
with open("bootstrap_data_2024_25.json", "r") as f:
    data = json.load(f)

bootstrap_api_pd = pd.DataFrame(data['elements'])

# %%
print(bootstrap_api_pd.columns.to_list())
# Out:
# ['can_transact', 'can_select', 'chance_of_playing_next_round', 'chance_of_playing_this_round', 'code', 'cost_change_event', 'cost_change_event_fall', 'cost_change_start', 'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next', 'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam', 'news', 'news_added', 'now_cost', 'photo', 'points_per_game', 'removed', 'second_name', 'selected_by_percent', 'special', 'squad_number', 'status', 'team', 'team_code', 'total_points', 'transfers_in', 'transfers_in_event', 'transfers_out', 'transfers_out_event', 'value_form', 'value_season', 'web_name', 'region', 'team_join_date', 'birth_date', 'has_temporary_code', 'opta_code', 'minutes', 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded', 'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards', 'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat', 'ict_index', 'starts', 'expected_goals', 'expected_assists', 'expected_goal_involvements', 'expected_goals_conceded', 'mng_win', 'mng_draw', 'mng_loss', 'mng_underdog_win', 'mng_underdog_draw', 'mng_clean_sheets', 'mng_goals_scored', 'influence_rank', 'influence_rank_type', 'creativity_rank', 'creativity_rank_type', 'threat_rank', 'threat_rank_type', 'ict_index_rank', 'ict_index_rank_type', 'corners_and_indirect_freekicks_order', 'corners_and_indirect_freekicks_text', 'direct_freekicks_order', 'direct_freekicks_text', 'penalties_order', 'penalties_text', 'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90', 'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90', 'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type', 'form_rank', 'form_rank_type', 'points_per_game_rank', 'points_per_game_rank_type', 'selected_rank', 'selected_rank_type', 'starts_per_90', 'clean_sheets_per_90']

# %% [markdown]
# - There are a lot of columns, but we will use whichever we want to

# %%
players_managers_df = bootstrap_api_pd[['first_name','second_name','web_name','team_code','minutes','starts','birth_date','element_type','code']]
players_managers_df.set_index('code')
# Out:
#              first_name                second_name      web_name  team_code  \
# code
# 438098            Fábio            Ferreira Vieira  Fábio Vieira          3
# 205651          Gabriel          Fernando de Jesus       G.Jesus          3
# 226597          Gabriel       dos Santos Magalhães       Gabriel          3
# 219847              Kai                    Havertz       Havertz          3
# 463748             Karl                       Hein          Hein          3
# ...                 ...                        ...           ...        ...
# 516939         Emmanuel                    Agbadou       Agbadou         39
# 100040854  Vítor Manuel  de Oliveira Lopes Pereira       Pereira         39
# 531170           Nasser                      Djiga         Djiga         39
# 433312         Marshall                    Munetsi       Munetsi         39
# 647671           Mateus                       Mané          Mané         39
#
#            minutes  starts  birth_date  element_type
# code
# 438098           0       0        None             3
# 205651         600       6  1997-04-03             4
# 226597        2363      28  1997-12-19             2
# 219847        1872      21  1999-06-11             4
# 463748           0       0        None             1
# ...            ...     ...         ...           ...
# 516939        1410      16  1997-06-17             2
# 100040854        0       0  1968-07-26             5
# 531170          65       1  2002-11-15             2
# 433312        1077      12  1996-06-22             3
# 647671           1       0  2007-09-16             4
#
# [804 rows x 8 columns]

# %%
print(f'Number of entries: {players_managers_df.shape[0]}')
# Out:
# Number of entries: 804

# %% [markdown]
# It contains all managers, players who haven't played any minutes, so let's just remove them

# %%
managers_df =  players_managers_df[(players_managers_df['element_type'] == 5)]
managers_df
# Out:
#           first_name                second_name        web_name  team_code  \
# 32             Mikel                     Arteta          Arteta          3
# 79              Unai                      Emery           Emery          7
# 121           Andoni                     Iraola          Iraola         91
# 157           Thomas                      Frank           Frank         94
# 208           Fabian                   Hürzeler        Hürzeler         36
# 256             Enzo                    Maresca         Maresca          8
# 297           Oliver                    Glasner         Glasner         31
# 330            David                      Moyes           Moyes         11
# 364  Marco Alexandre           Saraiva da Silva           Silva         54
# 402           Kieran                    McKenna         McKenna         40
# 442             Ruud            van Nistelrooij  Van Nistelrooy         13
# 481             Arne                       Slot            Slot         14
# 517              Pep                  Guardiola       Guardiola         43
# 555     Ruben Filipe       Marques Diogo Amorim          Amorim          1
# 597            Eddie                       Howe            Howe          4
# 633   Nuno Herlander      Simões Espírito Santo            Nuno         17
# 674            Simon                       Rusk            Rusk         20
# 721             Ange                Postecoglou     Postecoglou          6
# 757           Graham                     Potter          Potter         21
# 800     Vítor Manuel  de Oliveira Lopes Pereira         Pereira         39
#
#      minutes  starts  birth_date  element_type       code
# 32         0       0  1982-03-26             5  100051017
# 79         0       0  1971-11-03             5  100037568
# 121        0       0  1982-06-22             5  100050427
# 157        0       0  1973-10-09             5  100042830
# 208        0       0  1993-02-26             5  100053901
# 256        0       0  1980-02-10             5  100048548
# 297        0       0  1974-08-28             5  100044409
# 330        0       0  1963-04-25             5  100000084
# 364        0       0  1977-07-12             5  100041800
# 402        0       0  1986-05-14             5  100047417
# 442        0       0  1976-07-01             5  100050995
# 481        0       0  1978-09-17             5  100052173
# 517        0       0  1971-01-18             5  100037973
# 555        0       0  1985-01-27             5  100053636
# 597        0       0  1977-11-29             5  100038215
# 633        0       0  1974-01-25             5  100041808
# 674        0       0  1981-12-17             5  100047426
# 721        0       0  1965-08-27             5  100041880
# 757        0       0  1975-05-20             5  100046435
# 800        0       0  1968-07-26             5  100040854

# %%
players_who_played = players_managers_df[players_managers_df['minutes'] > 0]
players_who_played.head()
# Out:
#    first_name           second_name  web_name  team_code  minutes  starts  \
# 1     Gabriel     Fernando de Jesus   G.Jesus          3      600       6
# 2     Gabriel  dos Santos Magalhães   Gabriel          3     2363      28
# 3         Kai               Havertz   Havertz          3     1872      21
# 5     Jurriën                Timber  J.Timber          3     2415      27
# 6  Jorge Luiz          Frello Filho  Jorginho          3      701       9
#
#    birth_date  element_type    code
# 1  1997-04-03             4  205651
# 2  1997-12-19             2  226597
# 3  1999-06-11             4  219847
# 5  2001-06-17             2  445122
# 6  1991-12-20             3   85955

# %%
print(f'Number of players who have played atleast a minute: {players_who_played.shape[0]}')
# Out:
# Number of players who have played atleast a minute: 562

# %%
players_who_started = players_managers_df[players_managers_df['starts'] > 0]
players_who_started.head()
# Out:
#    first_name           second_name  web_name  team_code  minutes  starts  \
# 1     Gabriel     Fernando de Jesus   G.Jesus          3      600       6
# 2     Gabriel  dos Santos Magalhães   Gabriel          3     2363      28
# 3         Kai               Havertz   Havertz          3     1872      21
# 5     Jurriën                Timber  J.Timber          3     2415      27
# 6  Jorge Luiz          Frello Filho  Jorginho          3      701       9
#
#    birth_date  element_type    code
# 1  1997-04-03             4  205651
# 2  1997-12-19             2  226597
# 3  1999-06-11             4  219847
# 5  2001-06-17             2  445122
# 6  1991-12-20             3   85955

# %%
print(f'Number of players who have started atleast a match: {players_who_started.shape[0]}')
# Out:
# Number of players who have started atleast a match: 492

# %%
players_who_played['first_name'].value_counts().head()
# Out:
# first_name
# James    9
# Ben      7
# Harry    7
# Ryan     7
# Jack     6
# Name: count, dtype: int64

# %% [markdown]
# - There are 9 James who have played. Let's see who they are.

# %%
players_who_played[players_who_played['first_name'] == 'James']
# Out:
#     first_name  second_name     web_name  team_code  minutes  starts  \
# 90       James         Hill         Hill         91      443       6
# 180      James       Milner       Milner         36      170       3
# 305      James       Garner       Garner         11     1590      17
# 317      James    Tarkowski    Tarkowski         11     2922      33
# 419      James       Justin       Justin         13     2912      34
# 499      James       McAtee       McAtee         43      340       3
# 644      James         Bree         Bree         20     1070      13
# 694      James     Maddison     Maddison          6     1799      21
# 745      James  Ward-Prowse  Ward-Prowse         21     1433      17
#
#      birth_date  element_type    code
# 90   2002-01-10             2  463981
# 180  1986-01-04             3   15157
# 305  2001-03-13             3  232928
# 317  1992-11-19             2   17761
# 419  1998-02-23             2  220627
# 499  2002-10-18             3  432714
# 644  1997-12-11             2  184386
# 694  1996-11-23             3  172780
# 745  1994-11-01             3  101178

# %%
players_who_played = players_who_played.copy()
players_who_played[['year', 'month', 'day']] = players_who_played['birth_date'].str.split('-', expand=True)
players_who_played
# Out:
#      first_name           second_name  web_name  team_code  minutes  starts  \
# 1       Gabriel     Fernando de Jesus   G.Jesus          3      600       6
# 2       Gabriel  dos Santos Magalhães   Gabriel          3     2363      28
# 3           Kai               Havertz   Havertz          3     1872      21
# 5       Jurriën                Timber  J.Timber          3     2415      27
# 6    Jorge Luiz          Frello Filho  Jorginho          3      701       9
# ..          ...                   ...       ...        ...      ...     ...
# 796       Alfie                  Pond      Pond         39        1       0
# 799    Emmanuel               Agbadou   Agbadou         39     1410      16
# 801      Nasser                 Djiga     Djiga         39       65       1
# 802    Marshall               Munetsi   Munetsi         39     1077      12
# 803      Mateus                  Mané      Mané         39        1       0
#
#      birth_date  element_type    code  year month day
# 1    1997-04-03             4  205651  1997    04  03
# 2    1997-12-19             2  226597  1997    12  19
# 3    1999-06-11             4  219847  1999    06  11
# 5    2001-06-17             2  445122  2001    06  17
# 6    1991-12-20             3   85955  1991    12  20
# ..          ...           ...     ...   ...   ...  ..
# 796  2004-03-01             2  517179  2004    03  01
# 799  1997-06-17             2  516939  1997    06  17
# 801  2002-11-15             2  531170  2002    11  15
# 802  1996-06-22             3  433312  1996    06  22
# 803  2007-09-16             4  647671  2007    09  16
#
# [562 rows x 12 columns]

# %%
lfc_plaayer_df = players_who_played[players_who_played['team_code'] == 14]
lfc_plaayer_df.sort_values(by='minutes',ascending=False)
# Out:
#        first_name        second_name          web_name  team_code  minutes  \
# 464       Mohamed              Salah           M.Salah         14     3374
# 474        Virgil           van Dijk            Virgil         14     3330
# 459          Ryan        Gravenberch       Gravenberch         14     3160
# 465        Alexis       Mac Allister      Mac Allister         14     2597
# 462      Ibrahima             Konaté            Konaté         14     2561
# 447       Alisson      Ramses Becker          A.Becker         14     2508
# 472       Dominik         Szoboszlai        Szoboszlai         14     2485
# 471        Andrew          Robertson         Robertson         14     2479
# 463          Luis               Díaz         Luis Díaz         14     2393
# 448         Trent   Alexander-Arnold  Alexander-Arnold         14     2362
# 457          Cody              Gakpo             Gakpo         14     1921
# 460        Curtis              Jones             Jones         14     1702
# 453         Diogo  Teixeira da Silva          Diogo J.         14     1182
# 452        Darwin      Núñez Ribeiro            Darwin         14     1113
# 461      Caoimhin           Kelleher          Kelleher         14      900
# 473  Konstantinos           Tsimikas          Tsimikas         14      829
# 450         Conor            Bradley           Bradley         14      744
# 458           Joe              Gomez             Gomez         14      517
# 469        Jarell            Quansah           Quansah         14      488
# 455        Harvey            Elliott           Elliott         14      359
# 456          Endo             Wataru              Endo         14      259
# 475      Federico             Chiesa            Chiesa         14      103
# 476     Vítezslav              Jaros             Jaros         14       11
# 480        Jayden              Danns             Danns         14       10
#
#      starts  birth_date  element_type    code  year month   day
# 464      38  1992-06-15             3  118748  1992    06    15
# 474      37  1991-07-08             2   97032  1991    07    08
# 459      37  2002-05-16             3  441266  2002    05    16
# 465      30  1998-12-24             3  243016  1998    12    24
# 462      30  1999-05-25             2  204716  1999    05    25
# 447      28  1992-10-02             1  116535  1992    10    02
# 472      29  2000-10-25             3  424876  2000    10    25
# 471      29  1994-03-11             2  122798  1994    03    11
# 463      28  1997-01-13             3  244731  1997    01    13
# 448      28  1998-10-07             2  169187  1998    10    07
# 457      23  1999-05-07             4  243298  1999    05    07
# 460      19  2001-01-30             3  206915  2001    01    30
# 453      14  1996-12-04             3  194634  1996    12    04
# 452       8  1999-06-24             4  447203  1999    06    24
# 461      10  1998-11-23             1  200720  1998    11    23
# 473       9  1996-05-12             2  214285  1996    05    12
# 450       7  2003-07-09             2  492777  2003    07    09
# 458       6  1997-05-23             2  171287  1997    05    23
# 469       4  2003-01-29             2  441428  2003    01    29
# 455       2  2003-04-04             3  444884  2003    04    04
# 456       1  1993-02-09             3  158983  1993    02    09
# 475       1  1997-10-25             3  223541  1997    10    25
# 476       0  2001-07-23             1  432987  2001    07    23
# 480       0        None             4  500058  None  None  None

# %%
np.round(lfc_plaayer_df['year'].dropna().astype(int).describe(),2)
# Out:
# count      23.00
# mean     1997.78
# std         3.62
# min      1991.00
# 25%      1996.00
# 50%      1998.00
# 75%      2000.50
# max      2003.00
# Name: year, dtype: float64

# %%
players_who_played.sort_values(by='code').head(10)
# Out:
#     first_name      second_name   web_name  team_code  minutes  starts  \
# 180      James           Milner     Milner         36      170       3
# 317      James        Tarkowski  Tarkowski         11     2922      33
# 319     Ashley            Young      Young         11     1864      19
# 735     Łukasz        Fabiański  Fabianski         21     1160      13
# 528      Jonny            Evans      Evans          1      312       3
# 650       Adam          Lallana    Lallana         20      352       5
# 688     Fraser          Forster    Forster          6      630       7
# 365    Willian  Borges da Silva    Willian         54      251       2
# 188      Jason           Steele     Steele         36      180       2
# 194      Danny          Welbeck    Welbeck         36     2109      24
#
#      birth_date  element_type   code  year month day
# 180  1986-01-04             3  15157  1986    01  04
# 317  1992-11-19             2  17761  1992    11  19
# 319  1985-07-09             2  18892  1985    07  09
# 735  1985-04-18             1  37096  1985    04  18
# 528  1988-01-03             2  37642  1988    01  03
# 650  1988-05-10             3  39155  1988    05  10
# 688  1988-03-17             1  40383  1988    03  17
# 365  1988-08-09             3  47431  1988    08  09
# 188  1990-08-18             1  49262  1990    08  18
# 194  1990-11-26             4  50175  1990    11  26

# %% [markdown]
# Let's see who's birthday is in May

# %%
players_who_played[players_who_played['month'] == '06'].sort_values(by='day')
# Out:
#           first_name           second_name     web_name  team_code  minutes  \
# 445             Jake                 Evans   Jake Evans         13       21
# 16            Kieran               Tierney      Tierney          3      250
# 759            Rayan             Aït-Nouri    Aït-Nouri         39     3112
# 599             Álex         Moreno Lopera  Alex Moreno         17      952
# 190         Jan Paul             van Hecke    Van Hecke         36     2960
# 429             Luke                Thomas       Thomas         13     1109
# 3                Kai               Havertz      Havertz          3     1872
# 127             Mark               Flekken      Flekken         94     3275
# 15            Thomas                Partey       Thomas          3     2793
# 654             Ryan               Manning      Manning         20     1458
# 464          Mohamed                 Salah      M.Salah         14     3374
# 799         Emmanuel               Agbadou      Agbadou         39     1410
# 267            Chadi           Riad Dnanou   Chadi Riad         31       90
# 5            Jurriën                Timber     J.Timber          3     2415
# 101             Luis            Sinisterra   Sinisterra         91      229
# 8            Gabriel      Martinelli Silva   Martinelli          3     2284
# 240          Nicolas               Jackson    N.Jackson          8     2220
# 501  Rodrigo 'Rodri'             Hernandez      Rodrigo         43       72
# 802         Marshall               Munetsi      Munetsi         39     1077
# 25             Mikel                Merino       Merino          3     1575
# 432            Danny                  Ward         Ward         13      135
# 388             Jack                Taylor       Taylor         40      837
# 452           Darwin         Núñez Ribeiro       Darwin         14     1113
# 680          Rodrigo             Bentancur    Bentancur          6     1640
# 143      Igor Thiago  Nascimento Rodrigues       Thiago         94      167
# 301           Jarrad           Branthwaite  Branthwaite         11     2509
# 761      Jean-Ricner            Bellegarde   Bellegarde         39     1666
# 487            Kevin             De Bruyne    De Bruyne         43     1694
# 277    Jean-Philippe                Mateta       Mateta         31     2642
# 609          Nicolás             Domínguez    Dominguez         17     1954
# 661         Sugawara              Yukinari     Sugawara         20     1548
# 270         Eberechi                   Eze          Eze         31     2588
# 308              Tim            Iroegbunam   Iroegbunam         11      562
# 630           Felipe    Rodrigues da Silva       Morato         17      891
#
#      starts  birth_date  element_type    code  year month day
# 445       0  2008-06-04             3  630664  2008    06  04
# 16        2  1997-06-05             2  192895  1997    06  05
# 759      37  2001-06-06             2  448514  2001    06  06
# 599      11  1993-06-08             2  106468  1993    06  08
# 190      33  2000-06-08             2  469142  2000    06  08
# 429      13  2001-06-10             2  244619  2001    06  10
# 3        21  1999-06-11             4  219847  1999    06  11
# 127      37  1993-06-13             1  118342  1993    06  13
# 15       31  1993-06-13             3  167199  1993    06  13
# 654      18  1996-06-14             2  204863  1996    06  14
# 464      38  1992-06-15             3  118748  1992    06  15
# 799      16  1997-06-17             2  516939  1997    06  17
# 267       1  2003-06-17             2  515621  2003    06  17
# 5        27  2001-06-17             2  445122  2001    06  17
# 101       1  1999-06-17             3  224995  1999    06  17
# 8        25  2001-06-18             3  444145  2001    06  18
# 240      28  2001-06-20             4  517052  2001    06  20
# 501       1  1996-06-22             3  220566  1996    06  22
# 802      12  1996-06-22             3  433312  1996    06  22
# 25       17  1996-06-22             3  195384  1996    06  22
# 432       1  1993-06-22             1   95463  1993    06  22
# 388       4  1998-06-23             3  231899  1998    06  23
# 452       8  1999-06-24             4  447203  1999    06  24
# 680      21  1997-06-25             3  202993  1997    06  25
# 143       1  2001-06-26             4  502500  2001    06  26
# 301      28  2002-06-27             2  480455  2002    06  27
# 761      20  1998-06-27             3  231057  1998    06  27
# 487      19  1991-06-28             3   61366  1991    06  28
# 277      33  1997-06-28             4  231747  1997    06  28
# 609      23  1998-06-28             3  250199  1998    06  28
# 661      16  2000-06-28             2  219279  2000    06  28
# 270      31  1998-06-29             3  232413  1998    06  29
# 308       5  2003-06-30             3  490094  2003    06  30
# 630       6  2001-06-30             2  485047  2001    06  30

# %%
year_counts = players_who_played['year'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.xlabel("Year of Birth")
plt.ylabel("Count of Players")
plt.title("Distribution of Players by Birth Year")
plt.xticks(rotation=45) 
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(players_who_played['year'].sort_values(), kde=True, bins=30)
plt.xlabel("Year of Birth")
plt.ylabel("Count of Players")
plt.title("Distribution of Players by Birth Year (with KDE)")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
year_counts = players_who_played['month'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.xlabel("Month of Birth")
plt.ylabel("Count of Players")
plt.title("Distribution of Players by Birth Month")
plt.xticks(rotation=45) 
plt.grid(axis='y')
plt.show()

# %%
year_counts = players_who_played['day'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.xlabel("Day of Birth")
plt.ylabel("Count of Players")
plt.title("Distribution of Players by Birth Day")
plt.xticks(rotation=45) 
plt.grid(axis='y')
plt.show()

# %%
players_who_played[players_who_played['year'] == '2009'].sort_values(by='month')
# Out:
#     first_name second_name web_name  team_code  minutes  starts  birth_date  \
# 443     Jeremy       Monga    Monga         13      105       0  2009-07-10
#
#      element_type    code  year month day
# 443             3  649208  2009    07  10

# %%
players_who_played[players_who_played['year'] == '1985'].sort_values(by='minutes',ascending=False)
# Out:
#     first_name second_name   web_name  team_code  minutes  starts  birth_date  \
# 319     Ashley       Young      Young         11     1864      19  1985-07-09
# 735     Łukasz   Fabiański  Fabianski         21     1160      13  1985-04-18
#
#      element_type   code  year month day
# 319             2  18892  1985    07  09
# 735             1  37096  1985    04  18
